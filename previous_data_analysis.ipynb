# %% [markdown]
# <a href="https://colab.research.google.com/github/srik15/data_analysis/blob/main/previous_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np;
import warnings
import matplotlib.pyplot as plt
import seaborn as sns

# %%
warnings.filterwarnings('ignore')

# %%
# pd.set_option('display.max_colums',None)
df=pd.read_csv('previous_application.csv')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12784 entries, 0 to 12783
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   SK_ID_PREV                   12784 non-null  int64
#  1   SK_ID_CURR                   12784 non-null  int64
#  2   NAME_CONTRACT_TYPE           12784 non-null  object
#  3   AMT_ANNUITY                  10125 non-null  float64
#  4   AMT_APPLICATION              12784 non-null  float64
#  5   AMT_CREDIT                   12784 non-null  float64
#  6   AMT_DOWN_PAYMENT             6379 non-null   float64
#  7   AMT_GOODS_PRICE              10086 non-null  float64
#  8   WEEKDAY_APPR_PROCESS_START   12784 non-null  object
#  9   HOUR_APPR_PROCESS_START      12784 non-null  int64
#  10  FLAG_LAST_APPL_PER_CONTRACT  12784 non-null  object
#  11  NFLAG_LAST_APPL_IN_DAY       12784 non-null  int64
#  12  RATE_DOWN_PAYMENT            6379 non-null   float64
# ...

# %%
df.shape
# Out:
# (12784, 37)

# %%
df.isnull().sum()
# Out:
# SK_ID_PREV                         0
# SK_ID_CURR                         0
# NAME_CONTRACT_TYPE                 0
# AMT_ANNUITY                     2659
# AMT_APPLICATION                    0
# AMT_CREDIT                         0
# AMT_DOWN_PAYMENT                6405
# AMT_GOODS_PRICE                 2698
# WEEKDAY_APPR_PROCESS_START         0
# HOUR_APPR_PROCESS_START            0
# FLAG_LAST_APPL_PER_CONTRACT        0
# NFLAG_LAST_APPL_IN_DAY             0
# RATE_DOWN_PAYMENT               6405
# RATE_INTEREST_PRIMARY          12734
# RATE_INTEREST_PRIVILEGED       12734
# NAME_CASH_LOAN_PURPOSE             0
# NAME_CONTRACT_STATUS               0
# DAYS_DECISION                      0
# NAME_PAYMENT_TYPE                  0
# CODE_REJECT_REASON                 0
# NAME_TYPE_SUITE                 6212
# NAME_CLIENT_TYPE                   0
# NAME_GOODS_CATEGORY                0
# NAME_PORTFOLIO                     0
# NAME_PRODUCT_TYPE                  0
# ...

# %%
# df["CNT_PAYMENT"].nunique(axis=0)
df.CNT_PAYMENT.nunique()
# Out:
# 26

# %%
df.corr()
# Out:
#                            SK_ID_PREV  SK_ID_CURR  AMT_ANNUITY  \
# SK_ID_PREV                   1.000000   -0.003968     0.015893
# SK_ID_CURR                  -0.003968    1.000000    -0.002536
# AMT_ANNUITY                  0.015893   -0.002536     1.000000
# AMT_APPLICATION              0.006305   -0.000471     0.814771
# AMT_CREDIT                   0.007122    0.000983     0.824385
# AMT_DOWN_PAYMENT             0.012766   -0.003960     0.256845
# AMT_GOODS_PRICE              0.019968   -0.000710     0.830212
# HOUR_APPR_PROCESS_START      0.002288    0.014094    -0.021072
# NFLAG_LAST_APPL_IN_DAY      -0.005471   -0.002404     0.012838
# RATE_DOWN_PAYMENT           -0.018454    0.000246    -0.106657
# RATE_INTEREST_PRIMARY        0.002909    0.053978     0.261715
# RATE_INTEREST_PRIVILEGED     0.064679   -0.386854    -0.281032
# DAYS_DECISION                0.016481   -0.015029     0.270479
# SELLERPLACE_AREA             0.014235   -0.000296    -0.010143
# ...

# %%
sns.scatterplot(y=df['AMT_GOODS_PRICE'],x=df['CNT_PAYMENT']);

# %%
sns.scatterplot(x=df['AMT_APPLICATION'],y=df['AMT_CREDIT']);

# %%
sns.histplot(df[df["AMT_APPLICATION"]<250000],x='AMT_APPLICATION',bins=50);

# %%
sns.distplot(df['AMT_ANNUITY'])
# Out:
# <Axes: xlabel='AMT_ANNUITY', ylabel='Density'>

# %%
sns.distplot(df['AMT_CREDIT'])
# Out:
# <Axes: xlabel='AMT_CREDIT', ylabel='Density'>

# %%
sns.boxplot(y=df['AMT_APPLICATION']);

# %%
sns.boxplot(y=df['AMT_ANNUITY']);

# %%
sns.boxplot(y=df['AMT_CREDIT']);

# %%
sns.countplot(data=df,x='NAME_CONTRACT_TYPE')
# Out:
# <Axes: xlabel='NAME_CONTRACT_TYPE', ylabel='count'>

# %%
sns.countplot(data=df,x='WEEKDAY_APPR_PROCESS_START')
# Out:
# <Axes: xlabel='WEEKDAY_APPR_PROCESS_START', ylabel='count'>

# %%
sns.boxplot(data=df,x='NAME_CONTRACT_TYPE',y='AMT_ANNUITY');

# %%
sns.countplot(data=df,x='FLAG_LAST_APPL_PER_CONTRACT')
# Out:
# <Axes: xlabel='FLAG_LAST_APPL_PER_CONTRACT', ylabel='count'>

# %%
sns.countplot(data=df,x='NAME_CONTRACT_STATUS')
# Out:
# <Axes: xlabel='NAME_CONTRACT_STATUS', ylabel='count'>

# %%
plt.figure(figsize=(13,8));
sns.countplot(data=df,x='NAME_PAYMENT_TYPE')
# Out:
# <Axes: xlabel='NAME_PAYMENT_TYPE', ylabel='count'>

# %%
sns.countplot(data=df,x='CODE_REJECT_REASON')
# Out:
# <Axes: xlabel='CODE_REJECT_REASON', ylabel='count'>

# %%
sns.countplot(data=df,x='NAME_CLIENT_TYPE')
# Out:
# <Axes: xlabel='NAME_CLIENT_TYPE', ylabel='count'>

# %%
plt.figure(figsize=(10,7));
sns.countplot(data=df,y='NAME_GOODS_CATEGORY')
# Out:
# <Axes: xlabel='count', ylabel='NAME_GOODS_CATEGORY'>

# %%
sns.countplot(data=df,x='NAME_PORTFOLIO')
# Out:
# <Axes: xlabel='NAME_PORTFOLIO', ylabel='count'>

# %%
plt.figure(figsize=(15,7))
sns.countplot(data=df,x='CHANNEL_TYPE');

# %%
sns.countplot(data=df,y='NAME_SELLER_INDUSTRY');

# %%
plt.figure(figsize=(13,15))
sns.heatmap(df.corr(), annot=True,cmap="Oranges")
plt.show()

# %%
sns.regplot(data=df,x="RATE_INTEREST_PRIVILEGED",y="DAYS_DECISION")
# Out:
# <Axes: xlabel='RATE_INTEREST_PRIVILEGED', ylabel='DAYS_DECISION'>

# %%
sns.regplot(data=df,x="AMT_GOODS_PRICE",y="AMT_ANNUITY")
# Out:
# <Axes: xlabel='AMT_GOODS_PRICE', ylabel='AMT_ANNUITY'>
